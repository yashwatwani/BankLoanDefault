# %%
import pandas as pd
df=pd.read_csv('train_indessa.csv')

# %%
# sure shot dropping
df.drop(['mths_since_last_delinq','mths_since_last_major_derog','mths_since_last_record','desc',
         'verification_status_joint','batch_enrolled','sub_grade','title','zip_code','addr_state',
        'emp_title'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# grade                             0
# emp_length                    26891
# home_ownership                    0
# annual_inc                        3
# verification_status               0
# pymnt_plan                        0
# purpose                           0
# dti                               0
# delinq_2yrs                      16
# inq_last_6mths                   16
# open_acc                         16
# pub_rec                          16
# revol_bal                         0
# revol_util                      287
# total_acc                        16
# initial_list_status               0
# total_rec_int                     0
# total_rec_late_fee                0
# recoveries                        0
# collection_recovery_fee           0
# ...

# %%
df['total_rev_hi_lim']
# Out:
# 0         30800.0
# 1         32900.0
# 2         34900.0
# 3         24700.0
# 4         47033.0
#            ...
# 532423    24800.0
# 532424    17800.0
# 532425    24200.0
# 532426    23300.0
# 532427    21700.0
# Name: total_rev_hi_lim, Length: 532428, dtype: float64

# %%
df['tot_cur_bal'].value_counts()
# Out:
# 0.0         78
# 14511.0     17
# 19998.0     15
# 27316.0     15
# 5537.0      15
#             ..
# 74511.0      1
# 298043.0     1
# 74510.0      1
# 74509.0      1
# 262519.0     1
# Name: tot_cur_bal, Length: 251640, dtype: int64

# %%
df['emp_length'].value_counts()
# Out:
# 10+ years    175105
# 2 years       47276
# < 1 year      42253
# 3 years       42175
# 1 year        34202
# 5 years       33393
# 4 years       31581
# 7 years       26680
# 8 years       26443
# 6 years       25741
# 9 years       20688
# Name: emp_length, dtype: int64

# %%
df[df['last_week_pay'].isnull()]
# Out:
#         member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 21        1699807      12400        12400          12400.0  36 months
# 37       72929339      10000        10000          10000.0  60 months
# 77       72539472      20000        20000          20000.0  36 months
# 92       15349020       1500         1500           1500.0  36 months
# 107      72868375      35000        35000          35000.0  36 months
# ...           ...        ...          ...              ...        ...
# 532269   71320522      32200        32200          32200.0  60 months
# 532277   73518570       6950         6950           6950.0  36 months
# 532280   72738675      13600        13600          13600.0  60 months
# 532378   72768978      16000        16000          16000.0  60 months
# 532400   73414202      20000        20000          20000.0  36 months
#
#         int_rate grade  emp_length home_ownership  annual_inc  ... recoveries  \
# ...

# %%
df['emp_length'].replace('n/a', '0', inplace=True)
df['emp_length'].replace(to_replace='\+ years', value='', regex=True, inplace=True)
df['emp_length'].replace(to_replace=' years', value='', regex=True, inplace=True)
df['emp_length'].replace(to_replace='< 1 year', value='0', regex=True, inplace=True)
df['emp_length'].replace(to_replace=' year', value='', regex=True, inplace=True)

# %%
df['emp_length'].isnull().sum()
# Out:
# 26891

# %%
df['emp_length'].value_counts()
# Out:
# 10    175105
# 2      47276
# 0      42253
# 3      42175
# 1      34202
# 5      33393
# 4      31581
# 7      26680
# 8      26443
# 6      25741
# 9      20688
# Name: emp_length, dtype: int64

# %%
df['emp_length'] = pd.to_numeric(df['emp_length'], errors='coerce')

# %%
df['last_week_pay'].median
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     550     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 551     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     552
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#
# TypeError: must be str, not int
#
# ...

# %%
df['last_week_pay'].fillna(df['last_week_pay'].median(), inplace=True)

# %%
df['last_week_pay'] = df['last_week_pay'].str.extract('(\d+)', expand=False)
df['last_week_pay'] = df['last_week_pay'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f5885f304e5f> in <module>()
#       1 df['last_week_pay'] = df['last_week_pay'].str.extract('(\d+)', expand=False)
# ----> 2 df['last_week_pay'] = df['last_week_pay'].astype(int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5881             # else, only a single dtype is given
#    5882             new_data = self._data.astype(
# -> 5883                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5884             )
#    5885             return self._constructor(new_data).__finalize__(self)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
# ...

# %%
df['last_week_pay'] = df['last_week_pay'].astype(int)

# %%
df.isnull().sum()
# Out:
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
# term                           0
# int_rate                       0
# grade                          0
# emp_length                     0
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# pymnt_plan                     0
# purpose                        0
# dti                            0
# delinq_2yrs                   16
# inq_last_6mths                16
# open_acc                       0
# pub_rec                       16
# revol_bal                      0
# revol_util                     0
# total_acc                      0
# initial_list_status            0
# total_rec_int                  0
# total_rec_late_fee             0
# recoveries                     0
# collection_recovery_fee        0
# collections_12_mths_ex_med    95
# application_type               0
# ...

# %%
df['emp_length']=df['emp_length'].fillna(0)

# %%
df['emp_length'].isnull().sum()
# Out:
# 0

# %%
df['tot_coll_amt'].median()
# Out:
# 0.0

# %%
cols = ['term', 'loan_amnt', 'funded_amnt', 'last_week_pay', 'int_rate',  'annual_inc', 'dti',  'open_acc', 'revol_bal', 'revol_util', 'total_acc', 'total_rec_int','tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'emp_length']
for col in cols:
    print('Imputation with Median: %s' % (col))
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# Imputation with Median: term
# Imputation with Median: loan_amnt
# Imputation with Median: funded_amnt
# Imputation with Median: last_week_pay
# Imputation with Median: int_rate
# Imputation with Median: annual_inc
# Imputation with Median: dti
# Imputation with Median: open_acc
# Imputation with Median: revol_bal
# Imputation with Median: revol_util
# Imputation with Median: total_acc
# Imputation with Median: total_rec_int
# Imputation with Median: tot_coll_amt
# Imputation with Median: tot_cur_bal
# Imputation with Median: total_rev_hi_lim
# Imputation with Median: emp_length

# %%
df['term'] = df['term'].str.extract('(\d+)', expand=False)

# %%
df['term'] = df['term'].astype(int)

# %%
cols = ['acc_now_delinq', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'collections_12_mths_ex_med',
       'delinq_2yrs','inq_last_6mths','pub_rec']
for col in cols:
    print('Imputation with Zero: %s' % (col))
    df[col].fillna(0, inplace=True)
# Out:
# Imputation with Zero: acc_now_delinq
# Imputation with Zero: total_rec_late_fee
# Imputation with Zero: recoveries
# Imputation with Zero: collection_recovery_fee
# Imputation with Zero: collections_12_mths_ex_med
# Imputation with Zero: delinq_2yrs
# Imputation with Zero: inq_last_6mths
# Imputation with Zero: pub_rec

# %%
df.isnull().sum()
# Out:
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# grade                         0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# pymnt_plan                    0
# purpose                       0
# dti                           0
# delinq_2yrs                   0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# total_acc                     0
# initial_list_status           0
# total_rec_int                 0
# total_rec_late_fee            0
# recoveries                    0
# collection_recovery_fee       0
# collections_12_mths_ex_med    0
# application_type              0
# last_week_pay                 0
# ...

# %%
df['pub_rec'].median()
# Out:
# 0.0

# %%
df['purpose'].value_counts()
# Out:
# debt_consolidation    314989
# credit_card           123670
# home_improvement       31087
# other                  25652
# major_purchase         10284
# small_business          6146
# car                     5266
# medical                 5117
# moving                  3243
# vacation                2812
# house                   2170
# wedding                 1401
# renewable_energy         331
# educational              260
# Name: purpose, dtype: int64

# %%
le=['grade','home_ownership','verification_status','purpose','initial_list_status','application_type','pymnt_plan']
for i in le:
    print(df[i].value_counts())
# Out:
# 1    152713
# 2    147499
# 0     89107
# 3     83567
# 4     42495
# 5     13826
# 6      3221
# Name: grade, dtype: int64
# 1    265940
# 5    213668
# 4     52664
# 3       117
# 2        36
# 0         3
# Name: home_ownership, dtype: int64
# 1    197750
# 2    174702
# 0    159976
# Name: verification_status, dtype: int64
# 2     314989
# 1     123670
# 4      31087
# 9      25652
# 6      10284
# 11      6146
# 0       5266
# 7       5117
# 8       3243
# 12      2812
# 5       2170
# 13      1401
# 10       331
# 3        260
# Name: purpose, dtype: int64
# 0    274018
# 1    258410
# Name: initial_list_status, dtype: int64
# 0    532123
# 1       305
# Name: application_type, dtype: int64
# n    532420
# y         8
# Name: pymnt_plan, dtype: int64

# %%
le
# Out:
# ['grade',
#  'home_ownership',
#  'verification_status',
#  'purpose',
#  'initial_list_status',
#  'application_type',
#  'pymnt_plan']

# %%
import numpy as np
# Encode Label for Classifier
from sklearn.preprocessing import LabelEncoder

cat_cols = ['grade', 'sub_grade', 'emp_length', 'home_ownership', 'verification_status', 
            'pymnt_plan', 'purpose', 'initial_list_status', 'application_type', 
            'verification_status_joint', 'zip_code', 'addr_state']
le1 = {}

for col in le:
    le1[col] = LabelEncoder()
    df[col] = le1[col].fit_transform(df[col])
    le1[col].classes_ = np.append(le1[col].classes_, 'other')
    
    print('Encoded: ', col)
# Out:
# Encoded:  grade
# Encoded:  home_ownership
# Encoded:  verification_status
# Encoded:  purpose
# Encoded:  initial_list_status
# Encoded:  application_type
# Encoded:  pymnt_plan

# %%
df.iloc[0]
# Out:
# member_id                     58189336.00
# loan_amnt                        14350.00
# funded_amnt                      14350.00
# funded_amnt_inv                  14350.00
# term                                36.00
# int_rate                            19.19
# grade                                4.00
# emp_length                           9.00
# home_ownership                       4.00
# annual_inc                       28700.00
# verification_status                  1.00
# pymnt_plan                           0.00
# purpose                              2.00
# dti                                 33.88
# delinq_2yrs                          0.00
# inq_last_6mths                       1.00
# open_acc                            14.00
# pub_rec                              1.00
# revol_bal                        22515.00
# revol_util                          73.10
# total_acc                           28.00
# initial_list_status                  0.00
# ...

# %%
from sklearn.model_selection import train_test_split
X=df.drop(['loan_status','member_id'],axis=1)
y=df[['loan_status']]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.30,random_state =123)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score

# %%
    rf = RandomForestClassifier(n_estimators=100, verbose=5, n_jobs=-1)
    rf.fit(X_train, y_train)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.1s
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# ...

# %%
preds = rf.predict(X_test)
fpr1, tpr1, thr1 = roc_curve(y_test['loan_status'], preds)
auc1 = roc_auc_score(y_test['loan_status'], preds)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    2.8s finished

# %%
print(auc1)
rf.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.6750395296174366
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    2.8s finished
# 0.8419009697675438

# %%
fi = list(zip(X_train.columns.values, rf.feature_importances_))
fi = sorted(fi, key=lambda x: -x[1])
pd.DataFrame(fi, columns=["Feature","Importance"])
# Out:
#                        Feature  Importance
# 0                last_week_pay    0.114115
# 1                  tot_cur_bal    0.092196
# 2             total_rev_hi_lim    0.086329
# 3                     int_rate    0.065840
# 4                total_rec_int    0.062744
# 5                          dti    0.059124
# 6                    revol_bal    0.051007
# 7                   revol_util    0.049525
# 8                   annual_inc    0.044417
# 9                    total_acc    0.041425
# 10             funded_amnt_inv    0.036586
# 11                    open_acc    0.033671
# 12         initial_list_status    0.032491
# 13                   loan_amnt    0.032201
# 14                 funded_amnt    0.032026
# 15                  emp_length    0.024299
# 16                       grade    0.020398
# 17                     purpose    0.016514
# 18              inq_last_6mths    0.015599
# 19                        term    0.014192
# 20         verification_status    0.013385
# ...

# %%
df.columns
# Out:
# Index(['member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'int_rate', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'pymnt_plan', 'purpose', 'dti', 'delinq_2yrs',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'collections_12_mths_ex_med', 'application_type', 'last_week_pay',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'loan_status'],
#       dtype='object')

# %%
from sklearn.feature_selection import VarianceThreshold
#data=pd.read_csv('train_indessa.csv')
var_thresh = VarianceThreshold(threshold=0.1)
transformed_data = var_thresh.fit_transform(df)

# %%
transformed_data
# Out:
# array([[5.8189336e+07, 1.4350000e+04, 1.4350000e+04, ..., 2.8699000e+04,
#         3.0800000e+04, 0.0000000e+00],
#        [7.0011223e+07, 4.8000000e+03, 4.8000000e+03, ..., 9.9740000e+03,
#         3.2900000e+04, 0.0000000e+00],
#        [7.0255675e+07, 1.0000000e+04, 1.0000000e+04, ..., 3.8295000e+04,
#         3.4900000e+04, 0.0000000e+00],
#        ...,
#        [7.3576070e+06, 1.8725000e+04, 1.8725000e+04, ..., 2.6010000e+04,
#         2.4200000e+04, 1.0000000e+00],
#        [2.3182668e+07, 2.1000000e+04, 2.1000000e+04, ..., 2.9197000e+04,
#         2.3300000e+04, 0.0000000e+00],
#        [4.6122259e+07, 1.0000000e+04, 1.0000000e+04, ..., 4.7866000e+04,
#         2.1700000e+04, 0.0000000e+00]])

# %%
selected_cols = ['member_id', 'emp_length', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'sub_grade', 'int_rate',
                 'annual_inc', 'dti', 'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'revol_bal',
                 'revol_util', 'total_acc', 'total_rec_int', 'total_rec_late_fee', 'mths_since_last_major_derog',
                 'last_week_pay', 'tot_cur_bal', 'total_rev_hi_lim', 'tot_coll_amt', 'recoveries',
                 'collection_recovery_fee', 'term', 'acc_now_delinq', 'collections_12_mths_ex_med']
col=df.columns.tolist()

# %%
x=[i for i in col if i not in selected_cols]
x
# Out:
# ['grade',
#  'home_ownership',
#  'verification_status',
#  'pymnt_plan',
#  'purpose',
#  'delinq_2yrs',
#  'inq_last_6mths',
#  'pub_rec',
#  'initial_list_status',
#  'application_type',
#  'loan_status']

# %%
X=df.drop(['loan_status','member_id','home_ownership',
 'verification_status',
 'pymnt_plan',
 'purpose',
 'delinq_2yrs',
 'inq_last_6mths',
 'pub_rec',
 'initial_list_status',
 'application_type'],axis=1)
y=df[['loan_status']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.30,random_state =123)
rf = RandomForestClassifier(n_estimators=100, verbose=5, n_jobs=-1)
rf.fit(X_train, y_train)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.2s
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# ...

# %%
preds = rf.predict(X_test)
fpr1, tpr1, thr1 = roc_curve(y_test['loan_status'], preds)
auc1 = roc_auc_score(y_test['loan_status'], preds)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    2.4s finished

# %%
print(auc1)
rf.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# 0.686982341943642
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    2.3s finished
# 0.8477546344120354

# %%
fi = list(zip(X_train.columns.values, rf.feature_importances_))
fi = sorted(fi, key=lambda x: -x[1])
pd.DataFrame(fi, columns=["Feature","Importance"])
# Out:
#                        Feature  Importance
# 0                last_week_pay    0.124272
# 1                  tot_cur_bal    0.108408
# 2             total_rev_hi_lim    0.098134
# 3                     int_rate    0.085010
# 4                total_rec_int    0.072518
# 5                          dti    0.063976
# 6                    revol_bal    0.056427
# 7                   revol_util    0.054549
# 8                   annual_inc    0.048834
# 9                    total_acc    0.044694
# 10             funded_amnt_inv    0.038896
# 11                    open_acc    0.035916
# 12                 funded_amnt    0.033963
# 13                   loan_amnt    0.033718
# 14                  emp_length    0.026101
# 15                       grade    0.021922
# 16                        term    0.016581
# 17                  recoveries    0.012031
# 18                tot_coll_amt    0.011619
# 19     collection_recovery_fee    0.008946
# 20          total_rec_late_fee    0.001971
# ...

# %%
if X['funded_amnt_inv']!=0:
    X['loan_to_income'] = X['annual_inc']/X['funded_amnt_inv']
#finalTest['loan_to_income'] = finalTest['annual_inc']/finalTest['funded_amnt_inv']

X['avl_lines'] = X['total_acc'] - X['open_acc']
#finalTest['avl_lines'] = finalTest['total_acc'] - finalTest['open_acc']


# Interest paid so far
X['int_paid'] = X['total_rec_int'] + X['total_rec_late_fee']
#finalTest['int_paid'] = finalTest['total_rec_int'] + finalTest['total_rec_late_fee']


# Calculating EMIs paid (in terms of percent)
X['emi_paid_progress_perc'] = ((X['last_week_pay']/(X['term']/12*52+1))*100)
#finalTest['emi_paid_progress_perc'] = ((finalTest['last_week_pay']/(finalTest['term']/12*52+1))*100)


# Calculating total repayments received so far, in terms of EMI or recoveries after charge off
X['total_repayment_progress'] = ((X['last_week_pay']/(X['term']/12*52+1))*100) + ((X['recoveries']/X['funded_amnt_inv']) * 100)
#finalTest['total_repayment_progress'] = ((finalTest['last_week_pay']/(finalTest['term']/12*52+1))*100) + ((finalTest['recoveries']/finalTest['funded_amnt_inv']) * 100)

# %%
for i,j in df.items():
    print(i,j)
    break
# Out:
# member_id 0         58189336
# 1         70011223
# 2         70255675
# 3          1893936
# 4          7652106
#             ...
# 532423    31296187
# 532424    29403184
# 532425     7357607
# 532426    23182668
# 532427    46122259
# Name: member_id, Length: 532428, dtype: int64

# %%
df.desrcibe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db4a86f3a887> in <module>()
# ----> 1 df.desrcibe()
#
# NameError: name 'df' is not defined
